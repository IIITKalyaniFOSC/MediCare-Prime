# %% [markdown]
# Malaria Detection

# %%
import pandas as pd
import numpy as np
from numpy import loadtxt
import os
import matplotlib.pyplot as plt
import cv2
import tensorflow as tf
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelBinarizer
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Dense, Dropout, MaxPooling2D, Conv2D, Flatten, Input
from tensorflow.keras.applications import VGG16
from sklearn.metrics import classification_report, confusion_matrix
from tensorflow.keras.models import load_model
import pickle
from PIL import Image
from tensorflow.keras.models import load_model

# %%
dir="/content/drive/MyDrive/Dataset"

for dirname, _, filenames in os.walk(dir):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# /content/drive/MyDrive/Dataset/Test/Uninfected/C3thin_original_IMG_20150608_163002_cell_159.png
# /content/drive/MyDrive/Dataset/Test/Uninfected/C3thin_original_IMG_20150608_163002_cell_34.png
# /content/drive/MyDrive/Dataset/Test/Uninfected/C3thin_original_IMG_20150608_162922_cell_145.png
# /content/drive/MyDrive/Dataset/Test/Uninfected/C3thin_original_IMG_20150608_162922_cell_191.png
# /content/drive/MyDrive/Dataset/Test/Uninfected/C3thin_original_IMG_20150608_163002_cell_146.png
# /content/drive/MyDrive/Dataset/Test/Uninfected/C3thin_original_IMG_20150608_162922_cell_211.png
# /content/drive/MyDrive/Dataset/Test/Uninfected/C3thin_original_IMG_20150608_162922_cell_217.png
# /content/drive/MyDrive/Dataset/Test/Uninfected/C3thin_original_IMG_20150608_162922_cell_205.png
# /content/drive/MyDrive/Dataset/Test/Uninfected/2.png
# /content/drive/MyDrive/Dataset/Test/Uninfected/C3thin_original_IMG_20150608_163002_cell_195.png
# ...

# %%
training_set =  tf.keras.preprocessing.image_dataset_from_directory('/content/drive/MyDrive/Dataset/Train',
                                                 image_size = (224, 224)
                                               
                                                 )

test_set = tf.keras.preprocessing.image_dataset_from_directory('/content/drive/MyDrive/Dataset/Test',
                                           image_size = (224, 224)
                                           
                                            )
# Out:
# Found 416 files belonging to 2 classes.
# Found 134 files belonging to 2 classes.

# %%
model = Sequential()
model.add(Conv2D(filters=32, kernel_size=(3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Conv2D(filters=64, kernel_size=(3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Conv2D(filters=64, kernel_size=(3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Conv2D(filters=128, kernel_size=(3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.5))

model.add(Dense(3, activation='sigmoid'))

# %%
model.compile(loss='sparse_categorical_crossentropy',optimizer="adam", metrics=['accuracy'])
model.fit(training_set,validation_data=test_set,epochs = 20)
# Out:
# Epoch 1/20
# 13/13 [==============================] - 165s 8s/step - loss: 29.0815 - accuracy: 0.4517 - val_loss: 0.6879 - val_accuracy: 0.6716
# Epoch 2/20
# 13/13 [==============================] - 35s 3s/step - loss: 0.6958 - accuracy: 0.6571 - val_loss: 0.8070 - val_accuracy: 0.4776
# Epoch 3/20
# 13/13 [==============================] - 35s 3s/step - loss: 0.6140 - accuracy: 0.6486 - val_loss: 0.8986 - val_accuracy: 0.3358
# Epoch 4/20
# 13/13 [==============================] - 35s 3s/step - loss: 0.6407 - accuracy: 0.6485 - val_loss: 0.7071 - val_accuracy: 0.4925
# Epoch 5/20
# 13/13 [==============================] - 35s 3s/step - loss: 0.5952 - accuracy: 0.6998 - val_loss: 0.7415 - val_accuracy: 0.5000
# Epoch 6/20
# 13/13 [==============================] - 35s 3s/step - loss: 0.3881 - accuracy: 0.8431 - val_loss: 0.6031 - val_accuracy: 0.6716
# Epoch 7/20
# ...
